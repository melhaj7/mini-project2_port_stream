# %%
# %sql
-- 1. Create or overwrite our Gold table
CREATE OR REPLACE TABLE workspace.ais_db.gold_ais_table AS

-- 2. The Aggregation
SELECT 
    ship_name,
    MAX(speed_knots) AS max_speed,
    COUNT(*) AS total_pings
FROM 
    workspace.ais_db.silver_ais_table -- <--- FILL IN THE BLANK: Your Silver table (workspace.ais_db.silver_ais_table)
GROUP BY 
    ship_name  -- <--- FILL IN THE BLANK: What column are we grouping the data by to get 1 row per ship?
ORDER BY 
    max_speed DESC;

# %%
# %sql
SELECT * FROM workspace.ais_db.gold_ais_table
# Out:
# Databricks visualization. Run in Databricks to view.
